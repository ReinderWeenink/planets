# %%
import pandas

# %%
#open the csv file in preprocess/raw, seperate by comma
data = pandas.read_csv('raw\\exoplanet.eu_catalog_17-11-25_11_47_48.csv', sep=',')
#create a new column altered_name copy name, add prefix <s> and postfix </s>
data['altered_name'] = '<s>' + data['name'] + '</s>'
#save the altered_name column to a txt file in preprocess/processed called exoplanet_names.txt, one name per line, no index
data['altered_name'].to_csv('processed\\exoplanet_names.txt', index=False, header=False)
#print the first 5 rows of the dataframe
data.head(5)
# Out:
#         name planet_status   mass  mass_error_min  mass_error_max  mass_sini  \
# 0  109 Psc b     Confirmed  5.743           0.289           1.011     6.3830
# 1  112 Psc b     Confirmed    NaN           0.005           0.004     0.0330
# 2  112 Psc c     Confirmed  9.866           1.781           3.190        NaN
# 3   11 UMi b     Confirmed    NaN           1.100           1.100    11.0873
# 4  14 And Ab     Confirmed    NaN           0.230           0.230     4.6840
#
#    mass_sini_error_min  mass_sini_error_max  radius  radius_error_min  ...  \
# 0                0.078                0.078   1.152               NaN  ...
# 1                0.005                0.004     NaN               NaN  ...
# 2                  NaN                  NaN     NaN               NaN  ...
# 3                1.100                1.100     NaN               NaN  ...
# 4                0.230                0.230     NaN               NaN  ...
#
# ...
